# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
from matplotlib.image import imread
from PIL import Image
import cv2
import shutil
import numpy as np
from tqdm import tqdm
from collections import Counter
import albumentations as A
from albumentations.pytorch import ToTensorV2
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.utils import class_weight
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout,BatchNormalization,GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adamax, Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.models import load_model

from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

import warnings
warnings.filterwarnings('ignore')

# %%
landmarks_path= Path("/kaggle/input/final-landmark-dataset/Final Dataset 4 JPG")
classes = os.listdir(landmarks_path)
print(classes)
# Out:
# ['The Small Aten Temple', 'Qasr Qarun', 'Pyramid of Meidum', 'Temple of Kom Ombo', 'Temple of Luxor', 'Temple of Isis in Philae', 'Temple of Hathor in Philae', 'Pyramid of Senefru - Bent Pyramid of Senefru', 'Temple of Dakka', 'Temple of Hathor in Dendera', 'Temple of Maharraqa', 'Pyramids of Giza', 'Black Pyramid of Amenemhat III', 'Temple of Horus at Edfu', 'Famine Stele', 'Al Qurn', 'Small Temple of Hathor and Nefertari at Abu Simbel', 'Sphinx', 'Temple of Kalabsha', 'Ptolemaic Temple of Hathor in Deir el Medina', 'Kiosk of Trajan in Philae', 'Temple of Khonsu in Karnak', 'Temple of Karnak', 'Colossoi of Memnon', 'Pyramid of Seila', 'Temple of Hatshepsut in Deir El Bahari', 'Temple of Habu', 'Osireion', 'Ramessum', 'Pyramid of Saqqara - Pyramid of Djoser', 'Temple of Amada', 'Tomb of Horemheb in Saqqara', 'Pyramid of Sahure', 'Sphinx of Memphis', 'Temple of Seti I in Abydos', 'The Roman Mammisi in Dendera', 'Temple of Wadi es-Sebua - Temple of Ramesses II', 'Tomb of Petosiris', 'Temple of Merit Amun', 'Tomb of Isadora', 'Kiosk of Qertassi', 'The Great Temple of Ramesses II at Abu Simbel', 'Temple of Hibis', 'Temple of Esna', 'Speos of Horemheb', 'Temple of Nekhbet and Hathor at El Kab', 'Temple of Isis in Deir Shelwit', 'Pompeys Pillar - Serapeum of Alexandria', 'Temple of Derr', 'Pyramid of Hawara - White pyramid of Amnemhat III', 'Pyramid of Userkaf', 'Pyramid of Unas']

# %%
len(classes)
# Out:
# 52

# %% [markdown]
# ## Utility Functions

# %%
IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp"}

def list_subdirs(path: Path):
    return sorted([p for p in path.iterdir() if p.is_dir()])

def count_images_recursive(path: Path):
    return sum(1 for p in path.rglob("*") if p.suffix.lower() in IMG_EXTS)

def count_images_in_dir(path: Path):
    return sum(1 for p in path.iterdir() if p.suffix.lower() in IMG_EXTS)

# %%
def make_df(landmarks_path: Path):
    rows = []

    for class_dir in list_subdirs(landmarks_path):
        landmark_name = os.path.basename(class_dir)
        for p in class_dir.iterdir():
            if p.suffix.lower() in IMG_EXTS:
                rows.append({"label": str(landmark_name)  , "path": str(p)})

    df = pd.DataFrame(rows, columns=["label", "path"])
    return df

df=make_df(landmarks_path)
df.sample(10)
# Out:
#                           label  \
# 3592            Temple of Dakka
# 1164          Pyramid of Sahure
# 5267        Temple of Maharraqa
# 5952            Tomb of Isadora
# 5035         Temple of Kom Ombo
# 2113           Pyramids of Giza
# 4717   Temple of Isis in Philae
# 555                Famine Stele
# 2430           Pyramids of Giza
# 685   Kiosk of Trajan in Philae
#
#                                                    path
# 3592  /kaggle/input/final-landmark-dataset/Final Dat...
# 1164  /kaggle/input/final-landmark-dataset/Final Dat...
# 5267  /kaggle/input/final-landmark-dataset/Final Dat...
# 5952  /kaggle/input/final-landmark-dataset/Final Dat...
# 5035  /kaggle/input/final-landmark-dataset/Final Dat...
# 2113  /kaggle/input/final-landmark-dataset/Final Dat...
# 4717  /kaggle/input/final-landmark-dataset/Final Dat...
# 555   /kaggle/input/final-landmark-dataset/Final Dat...
# 2430  /kaggle/input/final-landmark-dataset/Final Dat...
# 685   /kaggle/input/final-landmark-dataset/Final Dat...

# %%
print("Dataframe shape:", df.shape)
# Out:
# Dataframe shape: (6000, 2)

# %% [markdown]
# ## Data Preprocessing

# %%
sns.countplot(data=df,x='label',palette='plasma',order=df['label'].value_counts().index )
df['label'].value_counts()
# Out:
# label
# Pyramids of Giza                                      814
# Temple of Hatshepsut in Deir El Bahari                455
# Pyramid of Senefru - Bent Pyramid of Senefru          439
# Colossoi of Memnon                                    436
# The Great Temple of Ramesses II at Abu Simbel         363
# Sphinx                                                337
# Pyramid of Saqqara - Pyramid of Djoser                252
# Ramessum                                              219
# Temple of Horus at Edfu                               192
# Kiosk of Trajan in Philae                             171
# Temple of Kom Ombo                                    161
# Temple of Luxor                                       146
# Temple of Isis in Philae                              144
# Temple of Hathor in Dendera                           114
# Pompeys Pillar - Serapeum of Alexandria               111
# Small Temple of Hathor and Nefertari at Abu Simbel     99
# Temple of Karnak                                       94
# Black Pyramid of Amenemhat III                         88
# Pyramid of Meidum                                      82
# Pyramid of Sahure                                      64
# Temple of Dakka                                        61
# Pyramid of Userkaf                                     59
# Pyramid of Hawara - White pyramid of Amnemhat III      58
# Temple of Merit Amun                                   58
# The Roman Mammisi in Dendera                           52
# Temple of Seti I in Abydos                             51
# Famine Stele                                           49
# Kiosk of Qertassi                                      46
# Temple of Kalabsha                                     46
# Temple of Wadi es-Sebua - Temple of Ramesses II        45
# The Small Aten Temple                                  45
# Temple of Isis in Deir Shelwit                         45
# Qasr Qarun                                             43
# Temple of Khonsu in Karnak                             41
# Sphinx of Memphis                                      40
# Temple of Habu                                         39
# Tomb of Petosiris                                      36
# Temple of Hibis                                        35
# Temple of Maharraqa                                    33
# Tomb of Horemheb in Saqqara                            32
# Speos of Horemheb                                      31
# Temple of Esna                                         30
# Temple of Hathor in Philae                             29
# Al Qurn                                                28
# Ptolemaic Temple of Hathor in Deir el Medina           27
# Temple of Amada                                        26
# Osireion                                               25
# Pyramid of Unas                                        25
# Tomb of Isadora                                        22
# Temple of Derr                                         22
# Pyramid of Seila                                       21
# Temple of Nekhbet and Hathor at El Kab                 19
# Name: count, dtype: int64

# %%
def show(title, img):
    plt.imshow(img)
    plt.title(title)
    plt.axis("off")
    plt.show()

def load_bgr(path):
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise ValueError(f"Could not read {path}")
    return img_bgr

def bgr_to_rgb(img_bgr):
    return cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# %%
image_size = 256
def resize(image, size=image_size):
  return cv2.resize(image,(size,size), interpolation=cv2.INTER_AREA)

# %%
train_aug = A.Compose([
    A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.2),
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=15, border_mode=cv2.BORDER_REPLICATE, p=0.5),  # make sure border_mode is set here too
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.15, rotate_limit=15, border_mode=cv2.BORDER_REPLICATE, p=0.6)
])

def apply_augmentation(image):
    return train_aug(image=image)["image"]

# %%
def normalize(image):
  return image/255.0

# %%
sample_row = df.iloc[3903]
sample_path = sample_row["path"]
sample_label = sample_row["label"]

# %%
image_BGR = load_bgr(sample_path)
image_RGB = bgr_to_rgb(image_BGR)

show("Original (RGB)", image_RGB)
print("Original shape:", image_RGB.shape, "dtype:", image_RGB.dtype)
# Out:
# Original shape: (416, 497, 3) dtype: uint8

# %%
image_resized= resize(image_RGB,image_size)
show(f"Resized to {image_size}x{image_size}", image_resized)
print("Resized shape:", image_resized.shape)
# Out:
# Resized shape: (256, 256, 3)

# %%
image_augmented = apply_augmentation(image_RGB)

plt.figure(figsize=(8,4))
plt.subplot(1,2,1); plt.imshow(image_RGB); plt.title("Before Augmentation"); plt.axis("off")
plt.subplot(1,2,2); plt.imshow(image_augmented); plt.title("After Augmentation");  plt.axis("off")
plt.show()

# %%
def preprocess_image(path, size=image_size, augment=False):
    image_BGR = load_bgr(path)
    image_RGB = bgr_to_rgb(image_BGR)
    image_resized = resize(image_RGB, size)

    if augment:
        image_processed = apply_augmentation(image_resized)
    else:
        image_processed = image_resized

    image_normalized = normalize(image_processed)
    return image_normalized

# %%
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

class TFDataset:
    def __init__(self, df, augment=False, batch_size=BATCH_SIZE, shuffle=True, image_size=image_size):
        self.df = df.reset_index(drop=True)
        self.augment = augment
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.image_size = image_size if isinstance(image_size, int) else image_size[0]
        self.dataset = self._build_dataset()

    def _load_and_preprocess(self, path, label):
        def _py_preprocess(path_str):
            path_str = path_str.decode("utf-8")
            img = preprocess_image(
                path_str,
                size=self.image_size,
                augment=self.augment
            )
            return img.astype("float32")

        img = tf.numpy_function(_py_preprocess, [path], tf.float32)
        img.set_shape((self.image_size, self.image_size, 3))
        return img, label

    def _build_dataset(self):
        paths = self.df["path"].values
        labels = self.df["label"].values.astype("float32")

        ds = tf.data.Dataset.from_tensor_slices((paths, labels))

        if self.shuffle:
            ds = ds.shuffle(buffer_size=len(self.df), reshuffle_each_iteration=True)

        ds = ds.map(self._load_and_preprocess, num_parallel_calls=AUTOTUNE)
        ds = ds.batch(self.batch_size)
        ds = ds.prefetch(AUTOTUNE)
        return ds

    def __iter__(self):
        return iter(self.dataset)

    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))

# %% [markdown]
# ## Model

# %% [markdown]
# ### Data Split

# %%
df.shape[0]
# Out:
# 6000

# %%
from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["label"],
    random_state=42
)

valid_df, test_df = train_test_split(
    temp_df,
    test_size=0.3,
    stratify=temp_df["label"],
    random_state=42
)

# %%
train_df['label'].value_counts()
# Out:
# label
# Pyramids of Giza                                      651
# Temple of Hatshepsut in Deir El Bahari                364
# Pyramid of Senefru - Bent Pyramid of Senefru          351
# Colossoi of Memnon                                    349
# The Great Temple of Ramesses II at Abu Simbel         290
# Sphinx                                                269
# Pyramid of Saqqara - Pyramid of Djoser                202
# Ramessum                                              175
# Temple of Horus at Edfu                               154
# Kiosk of Trajan in Philae                             137
# Temple of Kom Ombo                                    129
# Temple of Luxor                                       117
# Temple of Isis in Philae                              115
# Temple of Hathor in Dendera                            91
# Pompeys Pillar - Serapeum of Alexandria                89
# Small Temple of Hathor and Nefertari at Abu Simbel     79
# Temple of Karnak                                       75
# Black Pyramid of Amenemhat III                         70
# Pyramid of Meidum                                      66
# Pyramid of Sahure                                      51
# Temple of Dakka                                        49
# Pyramid of Userkaf                                     47
# Pyramid of Hawara - White pyramid of Amnemhat III      46
# Temple of Merit Amun                                   46
# The Roman Mammisi in Dendera                           42
# Temple of Seti I in Abydos                             41
# Famine Stele                                           39
# Temple of Kalabsha                                     37
# Kiosk of Qertassi                                      37
# The Small Aten Temple                                  36
# Temple of Wadi es-Sebua - Temple of Ramesses II        36
# Temple of Isis in Deir Shelwit                         36
# Qasr Qarun                                             34
# Temple of Khonsu in Karnak                             33
# Sphinx of Memphis                                      32
# Temple of Habu                                         31
# Tomb of Petosiris                                      29
# Temple of Hibis                                        28
# Temple of Maharraqa                                    26
# Tomb of Horemheb in Saqqara                            26
# Speos of Horemheb                                      25
# Temple of Esna                                         24
# Temple of Hathor in Philae                             23
# Ptolemaic Temple of Hathor in Deir el Medina           22
# Al Qurn                                                22
# Temple of Amada                                        21
# Pyramid of Unas                                        20
# Osireion                                               20
# Tomb of Isadora                                        18
# Temple of Derr                                         18
# Pyramid of Seila                                       17
# Temple of Nekhbet and Hathor at El Kab                 15
# Name: count, dtype: int64

# %%
print("Train size:", train_df.shape[0])
print("Test size:", test_df['label'].shape[0])
print("Valid size:", valid_df['label'].shape[0])
# Out:
# Train size: 4800
# Test size: 360
# Valid size: 840

# %%
"""import os
import cv2
from tqdm import tqdm

def get_multiplier(n):
    if n <= 50:
        return 10
    elif n <= 150:
        return 4
    elif n <= 300:
        return 2
    else:
        return 1

def generate_augmented_dataset(train_df, train_aug, output_dir="augmented_train"):
    os.makedirs(output_dir, exist_ok=True)

    for label, group in tqdm(train_df.groupby("label")):
        class_dir = os.path.join(output_dir, str(label).replace(" ", "_"))
        os.makedirs(class_dir, exist_ok=True)

        n_original = len(group)
        multiplier = get_multiplier(n_original)
        total_needed = n_original * multiplier

        counter = 0

        # save original images
        for _, row in group.iterrows():
            img = cv2.imread(row["path"])
            if img is None:
                continue

            cv2.imwrite(
                os.path.join(class_dir, f"{counter}_orig.jpg"),
                img
            )
            counter += 1

        # generate augmented images
        while counter < total_needed:
            for _, row in group.iterrows():
                img = cv2.imread(row["path"])
                if img is None:
                    continue

                aug_img = train_aug(image=img)["image"]
                cv2.imwrite(
                    os.path.join(class_dir, f"{counter}_aug.jpg"),
                    aug_img
                )
                counter += 1

                if counter >= total_needed:
                    break

        # 🔍 per-class report
        print(
            f"Class: {label} | "
            f"Original: {n_original} | "
            f"Multiplier: {multiplier} | "
            f"Target: {total_needed} | "
            f"Saved: {counter}"
        )

generate_augmented_dataset(train_df, train_aug, output_dir="augmented_train")"""
# Out:
# 100%|██████████| 52/52 [1:01:33<00:00, 71.03s/it]

# %%
augmented_data = []
base_dir = Path("/kaggle/input/landmarks-augmented-dataset/augmented_train")


for class_name in os.listdir(base_dir):
    class_dir = os.path.join(base_dir, class_name)
    if not os.path.isdir(class_dir):
        continue
    for fname in os.listdir(class_dir):
        path = os.path.join(class_dir, fname)
        augmented_data.append({"path": path, "label": class_name.replace("_", " ")})

aug_df = pd.DataFrame(augmented_data)
aug_df.shape
# Out:
# (17731, 2)

# %%
aug_df.sample(10)
# Out:
#                                                     path  \
# 1128   /kaggle/input/landmarks-augmented-dataset/augm...
# 15457  /kaggle/input/landmarks-augmented-dataset/augm...
# 9140   /kaggle/input/landmarks-augmented-dataset/augm...
# 17013  /kaggle/input/landmarks-augmented-dataset/augm...
# 6524   /kaggle/input/landmarks-augmented-dataset/augm...
# 15527  /kaggle/input/landmarks-augmented-dataset/augm...
# 17631  /kaggle/input/landmarks-augmented-dataset/augm...
# 10802  /kaggle/input/landmarks-augmented-dataset/augm...
# 10983  /kaggle/input/landmarks-augmented-dataset/augm...
# 9288   /kaggle/input/landmarks-augmented-dataset/augm...
#
#                                                    label
# 1128                                   Sphinx of Memphis
# 15457                         Temple of Hathor in Philae
# 9140   Small Temple of Hathor and Nefertari at Abu Si...
# 17013                                     Temple of Esna
# 6524        Pyramid of Senefru - Bent Pyramid of Senefru
# 15527                                         Qasr Qarun
# 17631                                Temple of Maharraqa
# 10802                           Temple of Isis in Philae
# 10983    Temple of Wadi es-Sebua - Temple of Ramesses II
# 9288   Small Temple of Hathor and Nefertari at Abu Si...

# %% [markdown]
# ### Label Encoding

# %%
encoder = LabelEncoder()

aug_df['label'] = encoder.fit_transform(aug_df['label'])

test_df['label'] = encoder.transform(test_df['label'])
valid_df['label'] = encoder.transform(valid_df['label'])

# %%
counts = aug_df['label'].value_counts()
counts.index = encoder.inverse_transform(counts.index.astype(int))

counts
# Out:
# Pyramids of Giza                                      651
# The Great Temple of Ramesses II at Abu Simbel         580
# Kiosk of Trajan in Philae                             548
# Sphinx                                                538
# Temple of Kom Ombo                                    516
# Temple of Dakka                                       490
# Pyramid of Userkaf                                    470
# Temple of Luxor                                       468
# Pyramid of Hawara - White pyramid of Amnemhat III     460
# Temple of Merit Amun                                  460
# Temple of Isis in Philae                              460
# The Roman Mammisi in Dendera                          420
# Temple of Seti I in Abydos                            410
# Pyramid of Saqqara - Pyramid of Djoser                404
# Famine Stele                                          390
# Temple of Kalabsha                                    370
# Kiosk of Qertassi                                     370
# Temple of Hatshepsut in Deir El Bahari                364
# Temple of Hathor in Dendera                           364
# The Small Aten Temple                                 360
# Temple of Wadi es-Sebua - Temple of Ramesses II       360
# Temple of Isis in Deir Shelwit                        360
# Pompeys Pillar - Serapeum of Alexandria               356
# Pyramid of Senefru - Bent Pyramid of Senefru          351
# Ramessum                                              350
# Colossoi of Memnon                                    349
# Qasr Qarun                                            340
# Temple of Khonsu in Karnak                            330
# Sphinx of Memphis                                     320
# Small Temple of Hathor and Nefertari at Abu Simbel    316
# Temple of Habu                                        310
# Temple of Horus at Edfu                               308
# Temple of Karnak                                      300
# Tomb of Petosiris                                     290
# Black Pyramid of Amenemhat III                        280
# Temple of Hibis                                       280
# Pyramid of Meidum                                     264
# Temple of Maharraqa                                   260
# Tomb of Horemheb in Saqqara                           260
# Speos of Horemheb                                     250
# Temple of Esna                                        240
# Temple of Hathor in Philae                            230
# Al Qurn                                               220
# Ptolemaic Temple of Hathor in Deir el Medina          220
# Temple of Amada                                       210
# Pyramid of Sahure                                     204
# Pyramid of Unas                                       200
# Osireion                                              200
# Tomb of Isadora                                       180
# Temple of Derr                                        180
# Pyramid of Seila                                      170
# Temple of Nekhbet and Hathor at El Kab                150
# Name: count, dtype: int64

# %% [markdown]
# ### Class Weights

# %%
aug_df['label'].values
# Out:
# array([39, 39, 39, ..., 41, 41, 41])

# %%
y = aug_df['label']  # convert strings to int

classes = np.unique(y)
class_weights_array = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y
)

class_weights = dict(zip(classes, class_weights_array))

print(class_weights)
# Out:
# {np.int64(0): np.float64(1.5499125874125874), np.int64(1): np.float64(1.2177884615384615), np.int64(2): np.float64(0.9770222614062155), np.int64(3): np.float64(0.8743096646942801), np.int64(4): np.float64(0.9215696465696466), np.int64(5): np.float64(0.622227681078046), np.int64(6): np.float64(1.7049038461538462), np.int64(7): np.float64(0.9578111495246326), np.int64(8): np.float64(1.5499125874125874), np.int64(9): np.float64(0.74126254180602), np.int64(10): np.float64(1.2915938228438228), np.int64(11): np.float64(1.671474358974359), np.int64(12): np.float64(0.8440118050266565), np.int64(13): np.float64(2.0057692307692307), np.int64(14): np.float64(0.9714551829936445), np.int64(15): np.float64(1.7049038461538462), np.int64(16): np.float64(0.7254909983633387), np.int64(17): np.float64(0.5237799834574028), np.int64(18): np.float64(1.0028846153846154), np.int64(19): np.float64(0.9742307692307692), np.int64(20): np.float64(1.0790530671859786), np.int64(21): np.float64(1.363923076923077), np.int64(22): np.float64(0.6337932513583071), np.int64(23): np.float64(1.0655649038461539), np.int64(24): np.float64(1.6237179487179487), np.int64(25): np.float64(0.6958791208791208), np.int64(26): np.float64(1.8943376068376068), np.int64(27): np.float64(1.420753205128205), np.int64(28): np.float64(1.0999379652605459), np.int64(29): np.float64(0.9367603550295858), np.int64(30): np.float64(1.48252508361204), np.int64(31): np.float64(0.9367603550295858), np.int64(32): np.float64(1.2177884615384615), np.int64(33): np.float64(1.1070804195804196), np.int64(34): np.float64(0.9471688034188034), np.int64(35): np.float64(0.74126254180602), np.int64(36): np.float64(0.9215696465696466), np.int64(37): np.float64(1.136602564102564), np.int64(38): np.float64(1.0332750582750583), np.int64(39): np.float64(0.6608154442456768), np.int64(40): np.float64(0.7285913872452334), np.int64(41): np.float64(1.3114644970414202), np.int64(42): np.float64(0.74126254180602), np.int64(43): np.float64(2.273205128205128), np.int64(44): np.float64(0.8316604127579738), np.int64(45): np.float64(0.9471688034188034), np.int64(46): np.float64(0.5878978779840849), np.int64(47): np.float64(0.8118589743589744), np.int64(48): np.float64(0.9471688034188034), np.int64(49): np.float64(1.3114644970414202), np.int64(50): np.float64(1.8943376068376068), np.int64(51): np.float64(1.1757957559681698)}

# %%
train_data = TFDataset(
    aug_df,
    augment=False,
    batch_size=BATCH_SIZE,
    shuffle=True,
    image_size=256)

val_data = TFDataset(
    valid_df,
    augment=False,
    batch_size=BATCH_SIZE,
    shuffle=False,
    image_size=256
)
# Out:
# I0000 00:00:1768951877.287196      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
print("Number of samples:", len(train_data.df))
print("Number of batches:", len(train_data))
# Out:
# Number of samples: 17731
# Number of batches: 555

# %% [markdown]
# ### Model Building and Training

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(512,512,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(52, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 512, 512, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512, 512, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 256, 256, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256, 256, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 128, 128, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128, 128, 256)  │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64, 64, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 52)             │         6,708 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,725,748 (6.58 MB)
#  Trainable params: 1,723,828 (6.58 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau


early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

# %%
history = model.fit(
    train_data.dataset,
    validation_data=val_data.dataset,
    epochs=30,
    class_weight=class_weights,
    callbacks=[early_stop,reduce_lr]
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768951894.494945     143 service.cc:152] XLA service 0x7f28201174c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1768951894.494986     143 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1768951895.598349     143 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/555 ━━━━━━━━━━━━━━━━━━━━ 2:27:17 16s/step - accuracy: 0.0000e+00 - loss: 4.2077
# I0000 00:00:1768951906.670463     143 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 86s 127ms/step - accuracy: 0.0571 - loss: 3.8892 - val_accuracy: 0.0452 - val_loss: 3.7751 - learning_rate: 0.0010
# Epoch 2/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 57s 102ms/step - accuracy: 0.1414 - loss: 3.2704 - val_accuracy: 0.2321 - val_loss: 2.7160 - learning_rate: 0.0010
# Epoch 3/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 102ms/step - accuracy: 0.2303 - loss: 2.7599 - val_accuracy: 0.3726 - val_loss: 2.3379 - learning_rate: 0.0010
# Epoch 4/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.3601 - loss: 2.1466 - val_accuracy: 0.2286 - val_loss: 3.0542 - learning_rate: 0.0010
# Epoch 5/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 57s 102ms/step - accuracy: 0.5143 - loss: 1.5418 - val_accuracy: 0.5869 - val_loss: 1.3396 - learning_rate: 0.0010
# Epoch 6/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.6576 - loss: 1.0951 - val_accuracy: 0.7774 - val_loss: 0.7510 - learning_rate: 0.0010
# Epoch 7/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.7665 - loss: 0.7355 - val_accuracy: 0.8202 - val_loss: 0.5837 - learning_rate: 0.0010
# Epoch 8/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.8476 - loss: 0.4750 - val_accuracy: 0.7619 - val_loss: 0.8187 - learning_rate: 0.0010
# Epoch 9/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.8773 - loss: 0.3788 - val_accuracy: 0.9190 - val_loss: 0.2537 - learning_rate: 0.0010
# Epoch 10/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9060 - loss: 0.3029 - val_accuracy: 0.9214 - val_loss: 0.2521 - learning_rate: 0.0010
# Epoch 11/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 57s 102ms/step - accuracy: 0.9228 - loss: 0.2397 - val_accuracy: 0.9643 - val_loss: 0.1302 - learning_rate: 0.0010
# Epoch 12/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9433 - loss: 0.1788 - val_accuracy: 0.9702 - val_loss: 0.1226 - learning_rate: 0.0010
# Epoch 13/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9484 - loss: 0.1582 - val_accuracy: 0.9464 - val_loss: 0.1970 - learning_rate: 0.0010
# Epoch 14/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9504 - loss: 0.1492 - val_accuracy: 0.9048 - val_loss: 0.3622 - learning_rate: 0.0010
# Epoch 15/30
# 554/555 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9580 - loss: 0.1360
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9580 - loss: 0.1360 - val_accuracy: 0.9583 - val_loss: 0.1323 - learning_rate: 0.0010
# Epoch 16/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9724 - loss: 0.0855 - val_accuracy: 0.9857 - val_loss: 0.0499 - learning_rate: 3.0000e-04
# Epoch 17/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9833 - loss: 0.0444 - val_accuracy: 0.9869 - val_loss: 0.0499 - learning_rate: 3.0000e-04
# Epoch 18/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9883 - loss: 0.0343 - val_accuracy: 0.9798 - val_loss: 0.0801 - learning_rate: 3.0000e-04
# Epoch 19/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9886 - loss: 0.0363 - val_accuracy: 0.9905 - val_loss: 0.0445 - learning_rate: 3.0000e-04
# Epoch 20/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9893 - loss: 0.0369 - val_accuracy: 0.9893 - val_loss: 0.0421 - learning_rate: 3.0000e-04
# Epoch 21/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9892 - loss: 0.0336 - val_accuracy: 0.9881 - val_loss: 0.0799 - learning_rate: 3.0000e-04
# Epoch 22/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9896 - loss: 0.0321 - val_accuracy: 0.9905 - val_loss: 0.0521 - learning_rate: 3.0000e-04
# Epoch 23/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9917 - loss: 0.0245 - val_accuracy: 0.9881 - val_loss: 0.0397 - learning_rate: 3.0000e-04
# Epoch 24/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9926 - loss: 0.0244 - val_accuracy: 0.9905 - val_loss: 0.0433 - learning_rate: 3.0000e-04
# Epoch 25/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9931 - loss: 0.0235 - val_accuracy: 0.9929 - val_loss: 0.0437 - learning_rate: 3.0000e-04
# Epoch 26/30
# 554/555 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9922 - loss: 0.0248
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9922 - loss: 0.0248 - val_accuracy: 0.9714 - val_loss: 0.1193 - learning_rate: 3.0000e-04
# Epoch 27/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9897 - loss: 0.0287 - val_accuracy: 0.9917 - val_loss: 0.0424 - learning_rate: 9.0000e-05
# Epoch 28/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9950 - loss: 0.0161 - val_accuracy: 0.9929 - val_loss: 0.0388 - learning_rate: 9.0000e-05
# Epoch 29/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 101ms/step - accuracy: 0.9964 - loss: 0.0131 - val_accuracy: 0.9917 - val_loss: 0.0519 - learning_rate: 9.0000e-05
# Epoch 30/30
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 56s 102ms/step - accuracy: 0.9968 - loss: 0.0133 - val_accuracy: 0.9940 - val_loss: 0.0415 - learning_rate: 9.0000e-05

# %% [markdown]
# ### Model Evaluation

# %%
losses=pd.DataFrame(history.history)

# %%
losses[['accuracy','val_accuracy']].plot()
plt.title('Model Accuracy during Training')
# Out:
# Text(0.5, 1.0, 'Model Accuracy during Training')

# %%
losses[['loss','val_loss']].plot()
plt.title('Model Loss during Training')
# Out:
# Text(0.5, 1.0, 'Model Loss during Training')

# %%
val_loss, val_accuracy=model.evaluate(val_data.dataset)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9914 - loss: 0.0390
# Validation Loss: 0.0388
# Validation Accuracy: 0.9929

# %%
test_data = TFDataset(
    test_df,
    augment=False,
    batch_size=BATCH_SIZE,
    shuffle=False,
    image_size=image_size,
)

# %%
print("Number of samples:", len(test_data.df))
print("Number of batches:", len(test_data))
# Out:
# Number of samples: 360
# Number of batches: 12

# %%
y_true = np.concatenate([y for x, y in val_data.dataset], axis=0)
y_pred = np.argmax(model.predict(val_data.dataset), axis=1)

print(classification_report(y_true, y_pred))
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         4
#          1.0       1.00      1.00      1.00        13
#          2.0       1.00      1.00      1.00        61
#          3.0       1.00      1.00      1.00         7
#          4.0       1.00      1.00      1.00         6
#          5.0       1.00      1.00      1.00        24
#          6.0       1.00      1.00      1.00         4
#          7.0       1.00      1.00      1.00        15
#          8.0       1.00      1.00      1.00         4
#          9.0       1.00      1.00      1.00         8
#         10.0       0.92      1.00      0.96        11
#         11.0       1.00      1.00      1.00         9
#         12.0       1.00      1.00      1.00        35
#         13.0       1.00      1.00      1.00         3
#         14.0       1.00      1.00      1.00        62
#         15.0       1.00      0.75      0.86         4
#         16.0       0.89      1.00      0.94         8
#         17.0       1.00      1.00      1.00       114
#         18.0       1.00      1.00      1.00         6
#         19.0       1.00      1.00      1.00        31
#         20.0       1.00      1.00      1.00        14
#         21.0       1.00      1.00      1.00         4
#         22.0       1.00      1.00      1.00        48
#         23.0       1.00      1.00      1.00         6
#         24.0       1.00      1.00      1.00         4
#         25.0       1.00      0.88      0.93         8
#         26.0       1.00      1.00      1.00         3
#         27.0       0.80      1.00      0.89         4
#         28.0       1.00      0.83      0.91         6
#         29.0       1.00      0.88      0.93        16
#         30.0       1.00      1.00      1.00         4
#         31.0       1.00      1.00      1.00        64
#         32.0       1.00      1.00      1.00         5
#         33.0       1.00      1.00      1.00        27
#         34.0       1.00      1.00      1.00         6
#         35.0       1.00      1.00      1.00        20
#         36.0       1.00      1.00      1.00         6
#         37.0       1.00      0.92      0.96        13
#         38.0       1.00      1.00      1.00         6
#         39.0       0.96      1.00      0.98        22
#         40.0       1.00      1.00      1.00        20
#         41.0       1.00      1.00      1.00         5
#         42.0       1.00      1.00      1.00         8
#         43.0       1.00      1.00      1.00         3
#         44.0       1.00      1.00      1.00         7
#         45.0       1.00      1.00      1.00         6
#         46.0       1.00      1.00      1.00        51
#         47.0       0.88      1.00      0.93         7
#         48.0       1.00      1.00      1.00         6
#         49.0       1.00      1.00      1.00         4
#         50.0       0.75      1.00      0.86         3
#         51.0       1.00      1.00      1.00         5
#
#     accuracy                           0.99       840
#    macro avg       0.98      0.99      0.98       840
# weighted avg       0.99      0.99      0.99       840

# %%
y_true = np.concatenate([y for x, y in test_data.dataset], axis=0)
y_pred = np.argmax(model.predict(test_data.dataset), axis=1)

print(classification_report(y_true, y_pred))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         2
#          1.0       1.00      1.00      1.00         5
#          2.0       0.96      1.00      0.98        26
#          3.0       1.00      1.00      1.00         3
#          4.0       1.00      0.67      0.80         3
#          5.0       1.00      1.00      1.00        10
#          6.0       1.00      1.00      1.00         1
#          7.0       1.00      1.00      1.00         7
#          8.0       1.00      1.00      1.00         1
#          9.0       1.00      1.00      1.00         4
#         10.0       0.83      1.00      0.91         5
#         11.0       1.00      1.00      1.00         4
#         12.0       1.00      1.00      1.00        15
#         13.0       1.00      1.00      1.00         1
#         14.0       1.00      0.96      0.98        26
#         15.0       1.00      1.00      1.00         1
#         16.0       1.00      1.00      1.00         4
#         17.0       0.98      0.98      0.98        49
#         18.0       1.00      1.00      1.00         3
#         19.0       1.00      0.92      0.96        13
#         20.0       1.00      1.00      1.00         6
#         21.0       1.00      1.00      1.00         2
#         22.0       1.00      1.00      1.00        20
#         23.0       0.67      1.00      0.80         2
#         24.0       0.50      1.00      0.67         1
#         25.0       1.00      1.00      1.00         4
#         26.0       1.00      1.00      1.00         1
#         27.0       1.00      1.00      1.00         2
#         28.0       1.00      1.00      1.00         2
#         29.0       1.00      1.00      1.00         7
#         30.0       1.00      1.00      1.00         2
#         31.0       1.00      1.00      1.00        27
#         32.0       1.00      1.00      1.00         2
#         33.0       1.00      1.00      1.00        11
#         34.0       1.00      1.00      1.00         3
#         35.0       1.00      1.00      1.00         9
#         36.0       1.00      1.00      1.00         3
#         37.0       1.00      1.00      1.00         6
#         38.0       1.00      1.00      1.00         2
#         39.0       1.00      1.00      1.00        10
#         40.0       1.00      1.00      1.00         9
#         41.0       1.00      1.00      1.00         2
#         42.0       1.00      0.75      0.86         4
#         43.0       1.00      1.00      1.00         1
#         44.0       1.00      1.00      1.00         3
#         45.0       1.00      0.67      0.80         3
#         46.0       1.00      1.00      1.00        22
#         47.0       0.75      1.00      0.86         3
#         48.0       1.00      1.00      1.00         3
#         49.0       1.00      1.00      1.00         2
#         50.0       1.00      1.00      1.00         1
#         51.0       1.00      1.00      1.00         2
#
#     accuracy                           0.98       360
#    macro avg       0.97      0.98      0.97       360
# weighted avg       0.99      0.98      0.98       360

# %%
report = classification_report(y_true, y_pred, output_dict=True)
df_report = pd.DataFrame(report).transpose()
df_report
# Out:
#               precision    recall  f1-score     support
# 0.0            1.000000  1.000000  1.000000    2.000000
# 1.0            1.000000  1.000000  1.000000    5.000000
# 2.0            0.962963  1.000000  0.981132   26.000000
# 3.0            1.000000  1.000000  1.000000    3.000000
# 4.0            1.000000  0.666667  0.800000    3.000000
# 5.0            1.000000  1.000000  1.000000   10.000000
# 6.0            1.000000  1.000000  1.000000    1.000000
# 7.0            1.000000  1.000000  1.000000    7.000000
# 8.0            1.000000  1.000000  1.000000    1.000000
# 9.0            1.000000  1.000000  1.000000    4.000000
# 10.0           0.833333  1.000000  0.909091    5.000000
# 11.0           1.000000  1.000000  1.000000    4.000000
# 12.0           1.000000  1.000000  1.000000   15.000000
# 13.0           1.000000  1.000000  1.000000    1.000000
# 14.0           1.000000  0.961538  0.980392   26.000000
# 15.0           1.000000  1.000000  1.000000    1.000000
# 16.0           1.000000  1.000000  1.000000    4.000000
# 17.0           0.979592  0.979592  0.979592   49.000000
# 18.0           1.000000  1.000000  1.000000    3.000000
# 19.0           1.000000  0.923077  0.960000   13.000000
# 20.0           1.000000  1.000000  1.000000    6.000000
# 21.0           1.000000  1.000000  1.000000    2.000000
# 22.0           1.000000  1.000000  1.000000   20.000000
# 23.0           0.666667  1.000000  0.800000    2.000000
# 24.0           0.500000  1.000000  0.666667    1.000000
# 25.0           1.000000  1.000000  1.000000    4.000000
# 26.0           1.000000  1.000000  1.000000    1.000000
# 27.0           1.000000  1.000000  1.000000    2.000000
# 28.0           1.000000  1.000000  1.000000    2.000000
# 29.0           1.000000  1.000000  1.000000    7.000000
# 30.0           1.000000  1.000000  1.000000    2.000000
# 31.0           1.000000  1.000000  1.000000   27.000000
# 32.0           1.000000  1.000000  1.000000    2.000000
# 33.0           1.000000  1.000000  1.000000   11.000000
# 34.0           1.000000  1.000000  1.000000    3.000000
# 35.0           1.000000  1.000000  1.000000    9.000000
# 36.0           1.000000  1.000000  1.000000    3.000000
# 37.0           1.000000  1.000000  1.000000    6.000000
# 38.0           1.000000  1.000000  1.000000    2.000000
# 39.0           1.000000  1.000000  1.000000   10.000000
# 40.0           1.000000  1.000000  1.000000    9.000000
# 41.0           1.000000  1.000000  1.000000    2.000000
# 42.0           1.000000  0.750000  0.857143    4.000000
# 43.0           1.000000  1.000000  1.000000    1.000000
# 44.0           1.000000  1.000000  1.000000    3.000000
# 45.0           1.000000  0.666667  0.800000    3.000000
# 46.0           1.000000  1.000000  1.000000   22.000000
# 47.0           0.750000  1.000000  0.857143    3.000000
# 48.0           1.000000  1.000000  1.000000    3.000000
# 49.0           1.000000  1.000000  1.000000    2.000000
# 50.0           1.000000  1.000000  1.000000    1.000000
# 51.0           1.000000  1.000000  1.000000    2.000000
# accuracy       0.983333  0.983333  0.983333    0.983333
# macro avg      0.974857  0.979760  0.972907  360.000000
# weighted avg   0.986908  0.983333  0.983588  360.000000

# %%
print("Overall precision:", report["weighted avg"]["precision"])
print("Overall recall:", report["weighted avg"]["recall"])
print("Overall f1-score:", report["weighted avg"]["f1-score"])
print("Overall accuracy:",report["accuracy"])
# Out:
# Overall precision: 0.9869084362139918
# Overall recall: 0.9833333333333333
# Overall f1-score: 0.9835881979244909
# Overall accuracy: 0.9833333333333333

# %% [markdown]
# ### Validate on unseen samples

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

def display_batch(dataset, encoder=None, n=9):
    batch = dataset.dataset.shuffle(buffer_size=1000).take(1)
    for images, labels in batch:
        preds = model.predict(images)
        preds_classes = np.argmax(preds, axis=1)
        break

    plt.figure(figsize=(12, 12))
    for i in range(n):
        plt.subplot(3, 3, i + 1)
        img = images[i].numpy()

        if img.min() < 0:
            img = (img + 1) / 2.0
        img = np.clip(img, 0, 1)

        plt.imshow(img)
        if encoder:
            true_label = encoder.inverse_transform([int(labels[i].numpy())])[0]
            pred_label = encoder.inverse_transform([preds_classes[i]])[0]
        else:
            true_label = int(labels[i].numpy())
            pred_label = preds_classes[i]

        plt.title(f"True: {true_label}\nPred: {pred_label}")
        plt.axis("off")
    plt.show()

display_batch(test_data, encoder=encoder, n=9)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
import pickle
model.save('/kaggle/working/custom_cnn.keras')

encoder_file = "label_encoder.pkl"

with open(encoder_file, "wb") as f:
    pickle.dump(encoder, f)

# %%
import netron
netron.start(r"C:\Uni\4th Year\GP\Implementation\Recognition\Landmarks\Custom CNN - AUG\custom_cnn.keras")
# Out:
# Serving 'C:\Uni\4th Year\GP\Implementation\Recognition\Landmarks\Custom CNN - AUG\custom_cnn.keras' at http://localhost:8080
# ('localhost', 8080)
