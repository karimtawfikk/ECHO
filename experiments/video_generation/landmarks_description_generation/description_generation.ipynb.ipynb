# %%
# !nvidia-smi
# Out:
# Sun Feb 15 13:58:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.83                 Driver Version: 581.83         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   42C    P8              1W /   30W |       8MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            9252    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           15792    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           30880    C+G   C:\Windows\explorer.exe               N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch

def main():
    print("torch:", torch.__version__)
    print("cuda available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print("cuda version (torch):", torch.version.cuda)
        print("gpu:", torch.cuda.get_device_name(0))
        x = torch.randn(2048, 2048, device="cuda")
        y = x @ x
        torch.cuda.synchronize()
        print("GPU matmul OK. y mean:", y.mean().item())
    else:
        print("No CUDA detected by PyTorch. (If you expected GPU, install a CUDA-enabled torch build.)")

if __name__ == "__main__":
    main()
# Out:
# torch: 2.7.1+cu118
# cuda available: True
# cuda version (torch): 11.8
# gpu: NVIDIA GeForce GTX 1650
# GPU matmul OK. y mean: -0.011083493940532207

# %%
import json
from pathlib import Path
import torch
import gc
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM,  AutoModelForCausalLM,  BitsAndBytesConfig

# %%
def clear_mem():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()

# %%
DOCS_DIR = Path("docs")
OUT_DIR  = Path("data/video_generation/outputs")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
MODELS = {
    "flan_t5_large": {"type": "seq2seq", "id": "google/flan-t5-large"},
}

# %%
# GENERATION SETTINGS 
MAX_INPUT_TOKENS_SEQ2SEQ = 1024       # truncation cap for seq2seq
MIN_NEW_TOKENS = 20
MAX_NEW_TOKENS = 120
NUM_BEAMS = 4

# %%
def summarize_seq2seq(model, tokenizer, text: str, device: str) -> str:
    input_text = (
    f"Summarize the following description in 2-3 sentences. "
    f"Write in a factual yet engaging tone, like a documentary narrator. "
    f"Include vivid and informative details, but do not use commands or imperatives:\n{text}"
)
    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        truncation=True,
        padding = True,
        max_length=MAX_INPUT_TOKENS_SEQ2SEQ,
    )
    inputs = {k: v.to(device) for k, v in inputs.items()}  # move tokenizer outputs to gpu
    
    with torch.no_grad():
        out_ids = model.generate(
            **inputs,
            do_sample=True,
            temperature=0.6,
            min_new_tokens=MIN_NEW_TOKENS,
            max_new_tokens=MAX_NEW_TOKENS,
            repetition_penalty=1.1,
        )
    return tokenizer.decode(out_ids[0], skip_special_tokens=True).strip()

# %%
def load_model(model_type: str, model_id: str, device: str):

    tok = AutoTokenizer.from_pretrained(model_id, use_fast=True)
    m = AutoModelForSeq2SeqLM.from_pretrained(model_id)
    m.to(device).eval()
    return tok, m

# %%
def main():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Device:", device)
    if device == "cuda":
        print("GPU:", torch.cuda.get_device_name(0))

    files = sorted(DOCS_DIR.glob("*.txt"))
    if not files:
        raise SystemExit(f"No .txt files found in: {DOCS_DIR.resolve()}")

    for model_name, cfg in MODELS.items():
        model_id = cfg["id"]
        model_type = cfg["type"]

        print("\n==============================")
        print(f"Model: {model_name}")
        print(f"HF id: {model_id}")
        print(f"Type : {model_type}")
        print("==============================")

        model_out_dir = OUT_DIR / model_name
        model_out_dir.mkdir(parents=True, exist_ok=True)

        clear_mem()
        tokenizer, model = load_model(model_type, model_id, device)

        for p in files:
            text = p.read_text(encoding="utf-8", errors="ignore").strip()
            print(f"[Text Size] {p.name} -> {len(text.split())} words")
            summary = summarize_seq2seq(model, tokenizer, text, device)
        

            print(f"[Summary Size] {p.name} -> {len(summary.split())} words")

            out_file = model_out_dir / p.name
            out_file.write_text(summary, encoding="utf-8")
            print(f"[Saved] {out_file}")

        # Free memory before next model
        del model
        torch.cuda.empty_cache()
        clear_mem()

# %%
if __name__ == "__main__":
    main()
# Out:
# Device: cuda
# GPU: NVIDIA GeForce GTX 1650
#
# ==============================
# Model: flan_t5_large
# HF id: google/flan-t5-large
# Type : seq2seq
# ==============================
# [Text Size] Kiosk of Trajan in Philae.txt -> 463 words
# [Summary Size] Kiosk of Trajan in Philae.txt -> 16 words
# [Saved] description_outputs_few\flan_t5_large\Kiosk of Trajan in Philae.txt
# [Text Size] Pompeys Pillar - Serapeum of Alexandria.txt -> 419 words
# [Summary Size] Pompeys Pillar - Serapeum of Alexandria.txt -> 18 words
# [Saved] description_outputs_few\flan_t5_large\Pompeys Pillar - Serapeum of Alexandria.txt
# [Text Size] Pyramid of Hawara - White pyramid of Amnemhat III.txt -> 730 words
# [Summary Size] Pyramid of Hawara - White pyramid of Amnemhat III.txt -> 18 words
# [Saved] description_outputs_few\flan_t5_large\Pyramid of Hawara - White pyramid of Amnemhat III.txt
# [Text Size] Pyramid of Userkaf.txt -> 840 words
# [Summary Size] Pyramid of Userkaf.txt -> 26 words
# [Saved] description_outputs_few\flan_t5_large\Pyramid of Userkaf.txt
# [Text Size] Pyramids of Giza.txt -> 1501 words
# [Summary Size] Pyramids of Giza.txt -> 23 words
# [Saved] description_outputs_few\flan_t5_large\Pyramids of Giza.txt
# [Text Size] Qasr Qarun.txt -> 596 words
# [Summary Size] Qasr Qarun.txt -> 15 words
# [Saved] description_outputs_few\flan_t5_large\Qasr Qarun.txt
# [Text Size] Temple of Hathor in Dendera.txt -> 1096 words
# [Summary Size] Temple of Hathor in Dendera.txt -> 14 words
# [Saved] description_outputs_few\flan_t5_large\Temple of Hathor in Dendera.txt
# [Text Size] Temple of Luxor.txt -> 624 words
# [Summary Size] Temple of Luxor.txt -> 21 words
# [Saved] description_outputs_few\flan_t5_large\Temple of Luxor.txt
# [Text Size] Temple of Wadi es-Sebua - Temple of Ramesses II.txt -> 907 words
# [Summary Size] Temple of Wadi es-Sebua - Temple of Ramesses II.txt -> 50 words
# [Saved] description_outputs_few\flan_t5_large\Temple of Wadi es-Sebua - Temple of Ramesses II.txt
# [Text Size] The Great Temple of Ramesses II at Abu Simbel.txt -> 1812 words
# [Summary Size] The Great Temple of Ramesses II at Abu Simbel.txt -> 59 words
# [Saved] description_outputs_few\flan_t5_large\The Great Temple of Ramesses II at Abu Simbel.txt
# [Text Size] Tomb of Isadora.txt -> 272 words
# [Summary Size] Tomb of Isadora.txt -> 9 words
# [Saved] description_outputs_few\flan_t5_large\Tomb of Isadora.txt
